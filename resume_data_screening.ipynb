# %% [markdown]
# # **NLP Project - Resume Screening Project**

# %% [markdown]
# **Importing the necessary libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Importing the dataset into dataframe and displaying the first 5 rows in it.

# %%
df = pd.read_csv('/kaggle/input/resume-dataset/ResumeDataSet.csv')
df.head()
# Out:
#        Category                                             Resume
# 0  Data Science  Skills * Programming Languages: Python (pandas...
# 1  Data Science  Education Details \r\nMay 2013 to May 2017 B.E...
# 2  Data Science  Areas of Interest Deep Learning, Control Syste...
# 3  Data Science  Skills â¢ R â¢ Python â¢ SAP HANA â¢ Table...
# 4  Data Science  Education Details \r\n MCA   YMCAUST,  Faridab...

# %% [markdown]
# # **# Data Exploration**

# %% [markdown]
# * Checking if the dataset has any null values or not

# %%
df.isnull().sum()
# Out:
# Category    0
# Resume      0
# dtype: int64

# %% [markdown]
# * Finding basic information about the dataset
#   * It has 962 rows and 2 columns
#   * Both the columns contains data of Object datatype i.e. string

# %%
print(df.shape)
print(df.info())
# Out:
# (962, 2)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 962 entries, 0 to 961
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Category  962 non-null    object
#  1   Resume    962 non-null    object
# dtypes: object(2)
# memory usage: 15.2+ KB
# None

# %% [markdown]
# * Looking at the Unique Categories

# %%
unique_categories = df['Category'].unique()
print(unique_categories)
# Out:
# ['Data Science' 'HR' 'Advocate' 'Arts' 'Web Designing'
#  'Mechanical Engineer' 'Sales' 'Health and fitness' 'Civil Engineer'
#  'Java Developer' 'Business Analyst' 'SAP Developer' 'Automation Testing'
#  'Electrical Engineering' 'Operations Manager' 'Python Developer'
#  'DevOps Engineer' 'Network Security Engineer' 'PMO' 'Database' 'Hadoop'
#  'ETL Developer' 'DotNet Developer' 'Blockchain' 'Testing']

# %% [markdown]
# * Exploring Categories - getting value counts of each category.

# %%
df['Category'].value_counts()
# Out:
# Category
# Java Developer               84
# Testing                      70
# DevOps Engineer              55
# Python Developer             48
# Web Designing                45
# HR                           44
# Hadoop                       42
# Sales                        40
# Data Science                 40
# Mechanical Engineer          40
# ETL Developer                40
# Blockchain                   40
# Operations Manager           40
# Arts                         36
# Database                     33
# Health and fitness           30
# PMO                          30
# Electrical Engineering       30
# Business Analyst             28
# DotNet Developer             28
# Automation Testing           26
# Network Security Engineer    25
# Civil Engineer               24
# SAP Developer                24
# Advocate                     20
# Name: count, dtype: int64

# %% [markdown]
# # **#Data Visualization**

# %% [markdown]
# # Creating a count plot of Categories
# Creating a bar chart visualization using Plotly to display the count of job categories from a DataFrame (df).
#
# plot_data = pd.DataFrame({
#     'Category': df['Category'].value_counts().index,
#     'Count': df['Category'].value_counts().values
# })
# This code creates a new DataFrame named plot_data to store the data that will be used for plotting. It is constructed using a Python dictionary with two keys: 'Category' and 'Count'. The 'Category' key contains unique job categories extracted from the 'Category' column, and the 'Count' key contains the corresponding count of each category.
# fig = px.bar(plot_data, x='Category', y='Count',
#              color='Category',
#              labels={'Category': 'Job', 'Count': 'Count'},
#              color_discrete_sequence=px.colors.qualitative.Set3)
# A bar chart is created using Plotly Express (px). The plot_data DataFrame is used as the data source for the plot. The 'Category' column values are plotted on the x-axis, and the 'Count' column values are plotted on the y-axis.
#
# It sets the color of the bars based on the 'Category' column values, which means each job category will have a different color in the chart.
#
# It sets the color palette to be used in the plot. It uses the qualitative color sequence 'Set3' from Plotly's predefined color palettes.

# %%
# Creating the bar plot
import plotly.express as px
import plotly.graph_objects as go
# Create a new DataFrame for plotting
plot_data = pd.DataFrame({
    'Category': df['Category'].value_counts().index,
    'Count': df['Category'].value_counts().values
})
plot_data.head()
fig = px.bar(plot_data, x='Category', y='Count',
             color='Category', 
             labels={'Category': 'Job', 'Count': 'Count'},
             color_discrete_sequence=px.colors.qualitative.Set3)

fig.update_layout(
    title='Count of a particular Job',
    xaxis_title='Job Type',
    yaxis_title='Count',
    legend_title='Job Categories',
    showlegend=True,
    xaxis=dict(tickangle=-30),
    font=dict(family='Times New Roman', size=12),
    plot_bgcolor='white'
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="3e29e2a7-641c-4dcf-afb7-78f0febd58a3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("3e29e2a7-641c-4dcf-afb7-78f0febd58a3")) {                    Plotly.newPlot(                        "3e29e2a7-641c-4dcf-afb7-78f0febd58a3",                        [{"alignmentgroup":"True","hovertemplate":"Job=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Java Developer","marker":{"color":"rgb(141,211,199)","pattern":{"shape":""}},"name":"Java Developer","offsetgroup":"Java Developer","orientation":"v","showlegend":true,"textposition":"auto","x":["Java Developer"],"xaxis":"x","y":[84],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Job=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Testing","marker":{"color":"rgb(255,255,179)","pattern":{"shape":""}},"name":"Testing","offsetgroup":"Testing","orientation":"v","showlegend":true,"textposition":"auto","x":["Testing"],"xaxis":"x","y":[70],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Job=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DevOps Engineer","marker":{"color":"rgb(190,186,218)","pattern":{"shape":""}},"name":"DevOps Engineer","offsetgroup":"DevOps Engineer","orientation":"v","showlegend":true,"textposition":"auto","x":["DevOps Engineer"],"xaxis":"x","y":[55],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Job=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Python Developer","marker":{"color":"rgb(251,128,114)","pattern":{"shape":""}},"name":"Python Developer","offsetgroup":"Python Developer","orientation":"v","showlegend":true,"textposition":"auto","x":["Python Developer"],"xaxis":"x","y":[48],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Job=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Web Designing","marker":{"color":"rgb(128,177,211)","pattern":{"shape":""}},"name":"Web Designing","offsetgroup":"Web Designing","orientation":"v","showlegend":true,"textposition":"auto","x":["Web Designing"],"xaxis":"x","y":[45],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Job=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"HR","marker":{"color":"rgb(253,180,98)","pattern":{"shape":""}},"name":"HR","offsetgroup":"HR","orientation":"v","showlegend":true,"textposition":"auto","x":["HR"],"xaxis":"x","y":[44],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Job=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Hadoop","marker":{"color":"rgb(179,222,105)","pattern":{"shape":""}},"name":"Hadoop","offsetgroup":"Hadoop","orientation":"v","showlegend":true,"textposition":"auto","x":["Hadoop"],"xaxis":"x","y":[42],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Job=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Sales","marker":{"color":"rgb(252,205,229)","pattern":{"shape":""}},"name":"Sales","offsetgroup":"Sales","orientation":"v","showlegend":true,"textposition":"auto","x":["Sales"],"xaxis":"x","y":[40],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Job=%{x}\u003cbr\u003eCount=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Data Science","marker":{"color":"rgb(217,217,217)","pattern":{"shape":""}},"name":"Data Science","offsetgroup":"Data Science","orientation":"v","showlegend":true,"textposition":"auto","x":["Data Science"],"xaxis":"x","y":[40],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Job=%{x}\u003cbr\u00 ...

# %% [markdown]
# **#Pie plot of Job Category**
#
# fig = px.pie(plot_data, values='Count', names='Category',
#              title='Pie plot of Job Category',
#              color_discrete_sequence=px.colors.sequential.RdBu,
#              hole=0.4,
#              labels={'Category': 'Categories', 'Count': 'Count'},
#              opacity=0.8,
#              )
# Creates a pie chart using Plotly Express (px). The plot_data DataFrame serves as the data source for the pie chart. It specifies that the 'Count' column contains the values to be used for the size of the pie slices, and the 'Category' column contains the names for each slice.

# %%
fig = px.pie(plot_data, values='Count', names='Category',
             title='Pie plot of Job Category',
             color_discrete_sequence=px.colors.sequential.RdBu,
             hole=0.4,
             labels={'Category': 'Categories', 'Count': 'Count'},
             opacity=0.8,
             )

# Customize the layout
fig.update_layout(
    legend_title='Categories',
    font=dict(family='Times New Roman', size=16, color='black'),
    plot_bgcolor='white',
    margin=dict(t=50, b=50, l=50, r=50)
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="5139d297-cb62-4b6c-b880-a88cb403d84d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5139d297-cb62-4b6c-b880-a88cb403d84d")) {                    Plotly.newPlot(                        "5139d297-cb62-4b6c-b880-a88cb403d84d",                        [{"domain":{"x":[0.0,1.0],"y":[0.0,1.0]},"hole":0.4,"hovertemplate":"Categories=%{label}\u003cbr\u003eCount=%{value}\u003cextra\u003e\u003c\u002fextra\u003e","labels":["Java Developer","Testing","DevOps Engineer","Python Developer","Web Designing","HR","Hadoop","Sales","Data Science","Mechanical Engineer","ETL Developer","Blockchain","Operations Manager","Arts","Database","Health and fitness","PMO","Electrical Engineering","Business Analyst","DotNet Developer","Automation Testing","Network Security Engineer","Civil Engineer","SAP Developer","Advocate"],"legendgroup":"","name":"","opacity":0.8,"showlegend":true,"values":[84,70,55,48,45,44,42,40,40,40,40,40,40,36,33,30,30,30,28,28,26,25,24,24,20],"type":"pie"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":" ...

# %% [markdown]
# # #Data Processing

# %%
# Preprocessing libraries
import re
from sklearn.preprocessing import LabelEncoder
import nltk
from nltk.corpus import stopwords
nltk.download('stopwords')
nltk.download('wordnet')
from nltk.stem import WordNetLemmatizer 
import string
from sklearn.feature_extraction.text import TfidfVectorizer
# Out:
# [nltk_data] Downloading package stopwords to /usr/share/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /usr/share/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %% [markdown]
# **#Cleaning Data:**
#
# 1 Removing (URLs, hashtags, mentions, special letters, punctuations)
#
# 2 Tokenizing the cleaned text
#
# 3 Removing Stop Words
#
# 4 Performing Lemmatization on final text
#
# The resumeKeywords function removes URLs, hashtags, mentions, special characters, non-ASCII characters, multiple spaces, and stop words from the input text while also performing tokenization, lowercasing, and lemmatization to provide cleaned and processed text as output.
#
# Tokenization: Tokenization is the process of breaking a text into individual words or tokens. In this step, the text is split into its constituent words, which makes it easier to analyze and process. For example, the sentence "I love coding" would be tokenized into three tokens: "I," "love," and "coding."
#
# StopWords: Stopwords are common words that are typically removed from text during natural language processing to improve text analysis and reduce noise in the data.Examples of common stopwords in English include "the," "and," "in," "is," "of," "it," "to," and many others. Removing stopwords from text helps reduce the dimensionality of the data and focuses the analysis on more meaningful words
#
# Lemmatization: Lemmatization is the process of reducing words to their base or root form. This step is essential for text analysis because it reduces different forms of a word to a common base form. For example, the words "running" and "ran" would both be lemmatized to "run." This simplifies the text and ensures that similar words are treated as the same, which is crucial for accurate analysis and modeling.

# %%
import re
import nltk
import string
from nltk.stem import WordNetLemmatizer

def resumeKeywords(txt):   
    
    cleanText = re.sub(r'http\S+\s', ' ', txt)          
    cleanText = re.sub(r'#\S+\s', ' ', cleanText)      
    cleanText = re.sub(r'@\S+', ' ', cleanText)        
    
    # ✅ Safely remove punctuations
    cleanText = re.sub(r'[%s]' % re.escape(string.punctuation), ' ', cleanText)
    
    cleanText = re.sub(r'[^\x00-\x7f]', ' ', cleanText) 
    cleanText = re.sub(r'\s+', ' ', cleanText)         
    cleanText = cleanText.strip()                      
    
    #------------Tokenizing Cleaned Text--------------------------------------------------------
    tokenizer = nltk.tokenize.RegexpTokenizer(r'\w+')
    tokens = tokenizer.tokenize(cleanText)
    
    # Lowercasing
    words = [word.lower() for word in tokens]

    #-------------Removing Stop Words------------------------------------------------------------
    stopwords = nltk.corpus.stopwords.words('english')
    words_new = [word for word in words if word not in stopwords]

    #-----------Performing Lemmatization---------------------------------------------------------
    wn = WordNetLemmatizer() 
    lemm_text = [wn.lemmatize(word) for word in words_new]

    #----------Converting List into String-------------------------------------------------------
    processed_text = ' '.join(lemm_text)
    
    return processed_text

# %% [markdown]
# **- Testing the above custom function to remove certain details from Resume**

# %%
resumeKeywords(" https://www.github.com Software Engineer with 2 years of experience in Data Structures and Algorithms Agile Scrum, SDLC, C++, Java MVC, JavaScript, Web Development, Python " +
               "Data Science, Machine Learning / AI, and Mainframe technologies Programming Languages: 	C/C++, Java, Python, SQL, JCL, Cobol, DB2" + 
               "Frameworks: %#####	Java Spring, Spring boot, React, Angular, NodeJs" +
               "Tools: 	GIT, Visual Studio Code, Sublime, Spyder, Jupyter Notebook, Bluezone, Netbeans, Jira, Confluence, Kanban, CI/CD (Jenkins, GitLab, Azure-Devops), AWS," + 
               "Data-Bricks Libraries: 	NumPy, Pandas, Matplotlib, nltk, Scikit learn, TensorFlow, Keras Other: 	Problem-Solving, Quick Learner, Time-Management")
# Out:
# 'software engineer 2 year experience data structure algorithm agile scrum sdlc c java mvc javascript web development python data science machine learning ai mainframe technology programming language c c java python sql jcl cobol db2frameworks java spring spring boot react angular nodejstools git visual studio code sublime spyder jupyter notebook bluezone netbeans jira confluence kanban ci cd jenkins gitlab azure devops aws data brick library numpy panda matplotlib nltk scikit learn tensorflow kera problem solving quick learner time management'

# %% [markdown]
# **#Applying above created Custom Function to process the data and creating new column "Processed_Resume"**

# %%
df['Processed_Resume'] = df['Resume'].apply(lambda x: resumeKeywords(x))
df.head()
# Out:
#        Category                                             Resume  \
# 0  Data Science  Skills * Programming Languages: Python (pandas...
# 1  Data Science  Education Details \r\nMay 2013 to May 2017 B.E...
# 2  Data Science  Areas of Interest Deep Learning, Control Syste...
# 3  Data Science  Skills â¢ R â¢ Python â¢ SAP HANA â¢ Table...
# 4  Data Science  Education Details \r\n MCA   YMCAUST,  Faridab...
#
#                                     Processed_Resume
# 0  skill programming language python panda numpy ...
# 1  education detail may 2013 may 2017 b e uit rgp...
# 2  area interest deep learning control system des...
# 3  skill r python sap hana tableau sap hana sql s...
# 4  education detail mca ymcaust faridabad haryana...

# %% [markdown]
# **#Generating WordCloud from the cleaned text**

# %%
# !pip install wordcloud
from wordcloud import WordCloud
# Out:
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.12/dist-packages (1.9.4)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.12/dist-packages (from wordcloud) (2.0.2)
# Requirement already satisfied: pillow in /usr/local/lib/python3.12/dist-packages (from wordcloud) (11.3.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from wordcloud) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->wordcloud) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->wordcloud) (1.17.0)

# %%
# Join the cleaned text into a single string
text = ' '.join(df['Processed_Resume'])

# Create a word cloud
wordcloud = WordCloud(background_color='white',
                      width=800,
                      height=600,
                      max_words=100,
                      colormap='viridis'
                      ).generate(text)

# Convert word cloud to an image
wordcloud_image = wordcloud.to_image()

# Display the word cloud using Plotly as an image
fig = px.imshow(wordcloud_image)
fig.update_layout(
    title='Word Cloud of Cleaned Text',
    xaxis_showticklabels=False,
    yaxis_showticklabels=False,
    plot_bgcolor='white'
)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="d9eb8bfb-adeb-4c0b-a325-c883b87e9b2a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d9eb8bfb-adeb-4c0b-a325-c883b87e9b2a")) {                    Plotly.newPlot(                        "d9eb8bfb-adeb-4c0b-a325-c883b87e9b2a",                        [{"name":"0","source":"...\u002fW53f39s2Gz2JBfF7vvJJ5\u002fd92ZnZ+ZmZ9\u002fOvJlBCIIAHz58+PDhw4cPHx0HyhT48OHj5kddp3vn\u002fh+Y0k6jukTJFLnh7P70dct2MqUtsf6bPQ8NWlpV7O1dbhy2fbfnycFv\u002fPXJP3Th1WPZ9NObgtM7L21Ytp0p9eHDh3vYTIEPHz6uE6XG9HUlr1Onr6f8iyIsmv4GRV2n+2fl4Sc+upup6DjufW5KcWYlU3ozMOeZKVw+R1uvpwt\u002ff3fTF4fepktufIbO6Dd0Rj+m9FanwVrxU8ES6vSZbmuknACa3kfLWDHjjsqvio1XuCh\u002fsGL2kIB5zBAt8WvhM7WWYqb0GhHClAdjP2dKbwzaZWAVqlULtm5UWywKgeDUw48ztGcrK5Ye3r\u002f3\u002focQhsI9Hi7BCQJFnMUt0\u002f+XFR+OmzA1oRtT4Z42XNJ+POTdHR7KpA2xtRl1rfbLp377YPOLTAUAAFQX14XGBjGlncPZ\u002fy7npRUvfGMOU3HTcnZ\u002f+oENZzhcdl2FauGrM3qPSFrz8b\u002fVJfVWk3XRW7Njuoc5B\u002fj6hXVmo0XiJ6Iieef+H7r1iakuUaYOSZi8YPgXz\u002fxutzk0Sv3Tn8+PTAz58Y0NmnqD1Wy79\u002fkp3fvHbvv5oEwhGXfnIIcde23Ol1\u002fsfIURgJY6AICizIq\u002fv\u002fqvNKfqi2d\u002fHzK51\u002fDpfRkpBICDm84e\u002fecCl8cZML6HX5A061zh50+uphLMyEKv4d1++N96vdpkt9ofeWdueByz8hAEQQ8QFhP45fNrcQy\u002fdCR78KRez391v3MWGDE4c\u002fVY9tr3N7PYLIvR+ul\u002frwvE\u002fL8++efSwXQAGDK9350vTM8+V7Dh839RNktTqw2KDnht9ZMIgvz92b9phzIInAiNC3rx58XZ5wo2f7Vr6d\u002fPAcAH87+584XpyYMSGDcqyaxYv+zf\u002fLTipXOWA8D7W15CUOTbp1dV5FdbTNYBE3s98PadLu\u002fFSOHxbedqSpQPLJ0HAGvf3xwSEzjpgdGMewEAI4UAsPu3Q0c2nsYxvNeo5AfevhMAls5Z3mdMSubpPFW15pOd\u002fzuy6bSyooFUrVq6ISw+eMqiMdt\u002f2r\u002f\u002fj2N9xvZ45MN7yZidS8w5Zh8+AOCcanuu\u002fgwA2HDzwdrViZLBCl4EM9AtSrsMrHg\u002f\u002fzOPLPknJ\u002fvzU8eYOgAAYKOs1r7g3V0yed2aPQseZKG38pimu7y7w3OZtDa2zkBdq932w74nl9\u002fPVPjwGgInXl3xUElO1d9f\u002fsfhccwGy+u\u002fPFJZVPfbe1vf\u002fn0JMwCXjSDw+i+PXjmZt\u002fXH\u002fWQM1SX1j39wd1hsIHn68veLAODU7ssnd6Xd89yUKydyP936gjxAQmon3jP06xfXjbtz0NWTecOm9SEIghGAQVyPiHlPTDi0+eyTn9wLAFnnixgp1KkMu9Yc+2LHywiKAMDZ\u002felCiYBKcO8RSdA8Cya9RSIXPf3Z\u002fJqy+p\u002ff2vTO2icYdzyz5yo9wBOf3KNXm97944m\u002fvtgVmRgKTllgXO4MjuHLHv3pqyPvBoT5kZLM03mZp\u002fOW7X8LAN6atSx1RBIAFF4tW5W+nMPjvDT+\u002fbLsyuiUiAN\u002fHn997dMJfWII3FtP1pgeEa\u002f8umTRqRc\u002f2PYyJXzyywfYXDaO4Qu7Pbdw6TxwuldkUhgjhePuGfbi+PcXvjkXQZGL+9PJpDrDSGF1Ue3h9ac+3\u002fcmgiD\u002fm\u002fpx3oWibgPiAIDL57y9\u002fnnykrH3DHtm+NL735xLEMTJf8+vOPMxAMxcMlEkE5RkVpBhnEvMXcw+fKhsVfRTjb2mtQaWiC1no1wHbmMqbnjaZWB5ZnB4xO77HmBKPeLukhqDoVCtYkpvLdzl3R2ey6S1sbWNr55aZdKbpf5iACAIYtnilXarXaPUPfP1g1FJYUXpZX99tr0kq2L54yuHTu877I7+jACM2N6995t31z\u002f3xNClTy6\u002fv6ZEKRDzT+28xAi\u002f9M4vk\u002frFVRXX9RzWbepDY1a\u002fu6m6WGkxWR9+766YlAgAyDyd\u002f9kjP9WVNSx8a07vUcnfv7BWrzbarPbHPrq3Iq+a7N+qr1R989wassvth5f+0NbrrWbbvS\u002ffkTwo3jnCVrGp7INaS3EIP+7OKNcvvDYQnRQKAGKpwGKyVOTXZJwt+GTxbwAQ2S3EOUBNWUN4fDAAhF8zpwCAJ+BS1pVRZ17x+nqxXKSq0UQkhCAI8uzyBV+\u002fsE4sFy754C6xXCiWC0UygU5lOLs\u002f\u002fd7npzgHoKJ1iXMKq0vro5NCSeuKhJ5gZ0lFYW1UUigAhEQF1JY3UFdRMAIEhvmx2OjXL6zTqQzTF40GAEYWmNc70VCtlirElK0AAGXZld36xyIIAgCJ\u002fWKL08tjUiMT+sRweBwAkAfJTAYLALyz8YVNX+6qKam764Xpg6b2pS4HABzD6acesFnsP7601my0cHkco9ZEXsi4l3MK2Vz2kGn9Lh64KvYT9R6TwuVzKBUdRgpLsyurCmten\u002fYJqTUZzORB6rAk6hK+iNd7dMrZ3Wk4TvQb35Mn5FIqCuf0uIvZR4fTGY1Mp6LghlPHKMIK4EXSlF4xP\u002foDALDjFhOmNTl0Jkx7SfVfnv4sM9yNR6cYWFV63byNf6stZh6LfWXJ05R8c3bm5eqqQrWqUK36Ydodn544VqHTrbxjdq\u002fgEHeXWDHHXZvWF6gaAKD7D1+TwpynX2AhCAD8cun871fStBZLj8DgpaPGpAYFA4Adw94+cnBHXo6Qw3m8\u002fyAeu+U8er7E5V1wglh+6sS2nCy1xRwgFM3pnvzS0BFk+DMV5V+eOZlRV4siSLyf\u002f6pZcxUCIQBkKeue3L1j9ay5r+7fm15XEyAUbb37viCRyF3eAaD\u002fLys+Gjfx54vnsuuVCf6KT8dPSg0K9lwm7mJz4PiyU8e35WTprbbBERHvjxkfJZMDwKBff3x39PhVly9m1NWGiCWvDBsxPbGptfVA5pl8BIE31z515Vj25m\u002f\u002fQxDk1ZWLAeDk9osn\u002f70Q9erMuJ5R856demj9qae+XEhewghAjw0A2GyWUWc ...

# %% [markdown]
# **#Encoding the Category column and plotting it**

# %%
# Label encoding our Category
label = LabelEncoder()
df['Encoded_Category'] = label.fit_transform(df['Category'])
df.head()
# Out:
#        Category                                             Resume  \
# 0  Data Science  Skills * Programming Languages: Python (pandas...
# 1  Data Science  Education Details \r\nMay 2013 to May 2017 B.E...
# 2  Data Science  Areas of Interest Deep Learning, Control Syste...
# 3  Data Science  Skills â¢ R â¢ Python â¢ SAP HANA â¢ Table...
# 4  Data Science  Education Details \r\n MCA   YMCAUST,  Faridab...
#
#                                     Processed_Resume  Encoded_Category
# 0  skill programming language python panda numpy ...                 6
# 1  education detail may 2013 may 2017 b e uit rgp...                 6
# 2  area interest deep learning control system des...                 6
# 3  skill r python sap hana tableau sap hana sql s...                 6
# 4  education detail mca ymcaust faridabad haryana...                 6

# %%
# Creating the bar plot
df['Encoded_Category'].value_counts().plot(kind = 'bar', title='Encoded Category counts', xlabel='Category', ylabel='counts')
plt.show()
df['Category'].value_counts().plot(kind = 'bar', title='Category counts', xlabel='Category', ylabel='Counts')
plt.show()

# %%
category_mapping = {
    15: "Java Developer",
    23: "Testing",
    8: "DevOps Engineer",
    20: "Python Developer",
    24: "Web Designing",
    12: "HR",
    13: "Hadoop",
    3: "Blockchain",
    10: "ETL Developer",
    18: "Operations Manager",
    6: "Data Science",
    22: "Sales",
    16: "Mechanical Engineer",
    1: "Arts",
    7: "Database",
    11: "Electrical Engineering",
    14: "Health and fitness",
    19: "PMO",
    4: "Business Analyst",
    9: "DotNet Developer",
    2: "Automation Testing",
    17: "Network Security Engineer",
    21: "SAP Developer",
    5: "Civil Engineer",
    0: "Advocate",
}

# %% [markdown]
# **#Vectorization (using TfidfVectorizer)**

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
tfidf = TfidfVectorizer(stop_words='english')

tfidf.fit(df['Processed_Resume'])
requiredText  = tfidf.transform(df['Processed_Resume'])
print(requiredText)
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 155341 stored elements and shape (962, 6562)>
#   Coords	Values
#   (0, 118)	0.06453783899846323
#   (0, 268)	0.04632697838273315
#   (0, 298)	0.031126979945512483
#   (0, 317)	0.025361912989866155
#   (0, 340)	0.033319272390464866
#   (0, 370)	0.029288428444891598
#   (0, 495)	0.13903194496767213
#   (0, 497)	0.07851286854091813
#   (0, 500)	0.15656008367123686
#   (0, 505)	0.02096423266463051
#   (0, 512)	0.026190077390818307
#   (0, 523)	0.04632697838273315
#   (0, 526)	0.03727134831379874
#   (0, 622)	0.04632697838273315
#   (0, 640)	0.053810183291968954
#   (0, 643)	0.08098518487138881
#   (0, 645)	0.02899820504264113
#   (0, 646)	0.06518168127424176
#   (0, 650)	0.10712314267369262
#   (0, 667)	0.03771995525102985
#   (0, 700)	0.027461726023211917
#   (0, 703)	0.03503454597093106
#   (0, 786)	0.015483241225769256
#   (0, 796)	0.08098518487138881
#   (0, 829)	0.024012779374943182
#   :	:
#   (961, 5265)	0.040106642718727006
#   (961, 5313)	0.034685407248807254
#   (961, 5323)	0.04300525885009774
#   (961, 5413)	0.029083167838973283
#   (961, 5473)	0.08173539261801048
#   (961, 5566)	0.03150101062479427
#   (961, 5581)	0.041292506952808554
#   (961, 5719)	0.056708709092727225
#   (961, 5723)	0.07957384679896679
#   (961, 5790)	0.07957384679896679
#   (961, 5855)	0.0913986709054804
#   (961, 5865)	0.02436657631243554
#   (961, 5896)	0.1862621097482243
#   (961, 5900)	0.38035443121688484
#   (961, 5964)	0.06521703489339466
#   (961, 6029)	0.13484105040549949
#   (961, 6222)	0.03260851744669733
#   (961, 6260)	0.07957384679896679
#   (961, 6283)	0.07162623562714822
#   (961, 6349)	0.17266809393032662
#   (961, 6352)	0.07324363253410175
#   (961, 6398)	0.07957384679896679
#   (961, 6427)	0.17433779453582576
#   (961, 6465)	0.4376490775067628
#   (961, 6526)	0.22233129749407932

# %% [markdown]
# # #Model Creation
# **#Splitting into Train and Test using (Vectorized text & Encoded category)**

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(requiredText, df['Encoded_Category'], test_size=0.25, random_state=42)
print(X_train.shape)

print(X_test.shape)
# Out:
# (721, 6562)
# (241, 6562)

# %% [markdown]
# **#Training the baseline model and printing its Accuracy**
#
# * KNeighbors Classifier
# * Multinomial NB

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.multiclass import OneVsRestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report

mnb = MultinomialNB()
mnb.fit(X_train,y_train)
y_pred1 = mnb.predict(X_test)
print('Accuracy: ', accuracy_score(y_test,y_pred1)*100, ' % \n')
print(classification_report(y_test, y_pred1))
# Out:
# Accuracy:  94.1908713692946  %
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.50      0.67         6
#            1       1.00      1.00      1.00         8
#            2       1.00      0.83      0.91         6
#            3       1.00      1.00      1.00        10
#            4       1.00      1.00      1.00         5
#            5       1.00      1.00      1.00         9
#            6       1.00      1.00      1.00         9
#            7       1.00      1.00      1.00         9
#            8       1.00      0.88      0.94        17
#            9       1.00      0.30      0.46        10
#           10       1.00      1.00      1.00         7
#           11       1.00      1.00      1.00         7
#           12       1.00      0.93      0.97        15
#           13       1.00      1.00      1.00         6
#           14       1.00      1.00      1.00        10
#           15       0.66      1.00      0.79        21
#           16       1.00      1.00      1.00        10
#           17       1.00      1.00      1.00         3
#           18       1.00      1.00      1.00        14
#           19       0.89      1.00      0.94         8
#           20       1.00      1.00      1.00        11
#           21       1.00      1.00      1.00         7
#           22       1.00      1.00      1.00         9
#           23       0.95      1.00      0.97        19
#           24       0.83      1.00      0.91         5
#
#     accuracy                           0.94       241
#    macro avg       0.97      0.94      0.94       241
# weighted avg       0.96      0.94      0.94       241

# %%
knc = OneVsRestClassifier(KNeighborsClassifier())
knc.fit(X_train,y_train)
y_pred2 = knc.predict(X_test)
print('Accuracy: ', accuracy_score(y_test,y_pred2)*100, ' %')
print(classification_report(y_test, y_pred2))
# Out:
# Accuracy:  98.3402489626556  %
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         6
#            1       1.00      1.00      1.00         8
#            2       1.00      1.00      1.00         6
#            3       1.00      1.00      1.00        10
#            4       1.00      1.00      1.00         5
#            5       1.00      1.00      1.00         9
#            6       1.00      0.78      0.88         9
#            7       1.00      1.00      1.00         9
#            8       1.00      0.88      0.94        17
#            9       1.00      1.00      1.00        10
#           10       1.00      1.00      1.00         7
#           11       1.00      1.00      1.00         7
#           12       1.00      1.00      1.00        15
#           13       1.00      1.00      1.00         6
#           14       1.00      1.00      1.00        10
#           15       1.00      1.00      1.00        21
#           16       1.00      1.00      1.00        10
#           17       1.00      1.00      1.00         3
#           18       0.93      1.00      0.97        14
#           19       1.00      1.00      1.00         8
#           20       1.00      1.00      1.00        11
#           21       0.78      1.00      0.88         7
#           22       1.00      1.00      1.00         9
#           23       1.00      1.00      1.00        19
#           24       0.83      1.00      0.91         5
#
#     accuracy                           0.98       241
#    macro avg       0.98      0.99      0.98       241
# weighted avg       0.99      0.98      0.98       241

# %% [markdown]
# **#Training the advanced model and printing its Accuracy**
#
# RNN

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, LSTM, Dense, SpatialDropout1D
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from sklearn.feature_extraction.text import TfidfVectorizer

# Define the maximum number of words to consider
max_words = 5000

# Tokenize and pad sequences
tokenizer = Tokenizer(num_words=max_words, split=' ')
tokenizer.fit_on_texts(df['Processed_Resume'])
X = tokenizer.texts_to_sequences(df['Processed_Resume'])
X = pad_sequences(X, maxlen=100)

# Split data into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, df['Encoded_Category'], test_size=0.25, random_state=42)

# Build the RNN model
model = Sequential()
model.add(Embedding(input_dim=max_words, output_dim=128, input_length=100))
model.add(SpatialDropout1D(0.2))
model.add(LSTM(100))
model.add(Dense(32, activation='relu'))
model.add(Dense(len(label.classes_), activation='softmax'))
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# Train the model
history = model.fit(X_train, y_train, validation_data=(X_test, y_test), epochs=50, batch_size=64)

# Evaluate the RNN model
# y_pred3 = model.predict(X_test)
y_pred_rnn_prob = model.predict(X_test)
y_pred3 = y_pred_rnn_prob.argmax(axis=-1)
accuracy_rnn = accuracy_score(y_test, y_pred3)
print('RNN Model Accuracy: {:.2f}%'.format(accuracy_rnn * 100))
print(classification_report(y_test, y_pred3))
# Out:
# 2026-01-13 05:21:12.173697: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768281672.417078      17 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768281672.496144      17 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768281673.113707      17 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768281673.113761      17 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768281673.113763      17 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768281673.113765      17 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# Epoch 1/50
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/embedding.py:97: UserWarning:
#
# Argument `input_length` is deprecated. Just remove it.
#
# 2026-01-13 05:21:26.966327: E external/local_xla/xla/stream_executor/cuda/cuda_platform.cc:51] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 122ms/step - accuracy: 0.0895 - loss: 3.2076 - val_accuracy: 0.1286 - val_loss: 3.1385
# Epoch 2/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.1108 - loss: 3.0574 - val_accuracy: 0.1909 - val_loss: 2.8562
# Epoch 3/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.2359 - loss: 2.8013 - val_accuracy: 0.3817 - val_loss: 2.6233
# Epoch 4/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.3503 - loss: 2.5159 - val_accuracy: 0.3859 - val_loss: 2.2251
# Epoch 5/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.4501 - loss: 2.0438 - val_accuracy: 0.4730 - val_loss: 1.7524
# Epoch 6/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.6131 - loss: 1.5742 - val_accuracy: 0.7344 - val_loss: 1.3071
# Epoch 7/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.7725 - loss: 1.1779 - val_accuracy: 0.7386 - val_loss: 1.1050
# Epoch 8/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.8027 - loss: 0.9148 - val_accuracy: 0.7967 - val_loss: 0.7753
# Epoch 9/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 98ms/step - accuracy: 0.8568 - loss: 0.6504 - val_accuracy: 0.9253 - val_loss: 0.5743
# Epoch 10/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.9251 - loss: 0.4789 - val_accuracy: 0.9046 - val_loss: 0.4175
# Epoch 11/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.9392 - loss: 0.3225 - val_accuracy: 0.9585 - val_loss: 0.2931
# Epoch 12/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.9726 - loss: 0.2524 - val_accuracy: 0.9710 - val_loss: 0.2090
# Epoch 13/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 0.9868 - loss: 0.2008 - val_accuracy: 0.9917 - val_loss: 0.1838
# Epoch 14/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.9923 - loss: 0.1441 - val_accuracy: 0.9917 - val_loss: 0.1566
# Epoch 15/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 0.9958 - loss: 0.1067 - val_accuracy: 0.9917 - val_loss: 0.1053
# Epoch 16/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.9970 - loss: 0.0666 - val_accuracy: 0.9793 - val_loss: 0.1441
# Epoch 17/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 0.9951 - loss: 0.0574 - val_accuracy: 0.9917 - val_loss: 0.1155
# Epoch 18/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.9964 - loss: 0.0420 - val_accuracy: 0.9668 - val_loss: 0.1543
# Epoch 19/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 0.9962 - loss: 0.0462 - val_accuracy: 0.9917 - val_loss: 0.1049
# Epoch 20/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 1.0000 - loss: 0.0224 - val_accuracy: 0.9917 - val_loss: 0.0918
# Epoch 21/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - accuracy: 1.0000 - loss: 0.0156 - val_accuracy: 0.9917 - val_loss: 0.0871
# Epoch 22/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 104ms/step - accuracy: 0.9953 - loss: 0.0305 - val_accuracy: 0.9917 - val_loss: 0.0870
# Epoch 23/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 0.9966 - loss: 0.0294 - val_accuracy: 0.9793 - val_loss: 0.1403
# Epoch 24/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 106ms/step - accuracy: 0.9941 - loss: 0.0418 - val_accuracy: 0.9917 - val_loss: 0.1210
# Epoch 25/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 108ms/step - accuracy: 0.9996 - loss: 0.0192 - val_accuracy: 0.9917 - val_loss: 0.1113
# Epoch 26/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 0.9962 - loss: 0.0217 - val_accuracy: 0.9917 - val_loss: 0.0782
# Epoch 27/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 97ms/step - accuracy: 1.0000 - loss: 0.0121 - val_accuracy: 0.9917 - val_loss: 0.0839
# Epoch 28/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 1.0000 - loss: 0.0083 - val_accuracy: 0.9917 - val_loss: 0.0882
# Epoch 29/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 1.0000 - loss: 0.0065 - val_accuracy: 0.9917 - val_loss: 0.0866
# Epoch 30/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 1.0000 - loss: 0.0055 - val_accuracy: 0.9917 - val_loss: 0.0878
# Epoch 31/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 96ms/step - accuracy: 1.0000 - loss: 0.0050 - val_accuracy: 0.9917 - val_loss: 0.0887
# Epoch 32/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 1.0000 - loss: 0.0045 - val_accuracy: 0.9917 - val_loss: 0.0894
# Epoch 33/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 1.0000 - loss: 0.0039 - val_accuracy: 0.9917 - val_loss: 0.0893
# Epoch 34/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 1.0000 - loss: 0.0037 - val_accuracy: 0.9917 - val_loss: 0.0886
# Epoch 35/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 1.0000 - loss: 0.0034 - val_accuracy: 0.9917 - val_loss: 0.0886
# Epoch 36/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 1.0000 - loss: 0.0033 - val_accuracy: 0.9917 - val_loss: 0.0873
# Epoch 37/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.9917 - val_loss: 0.0869
# Epoch 38/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 1.0000 - loss: 0.0028 - val_accuracy: 0.9917 - val_loss: 0.0871
# Epoch 39/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 102ms/step - accuracy: 1.0000 - loss: 0.0027 - val_accuracy: 0.9917 - val_loss: 0.0873
# Epoch 40/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 103ms/step - accuracy: 1.0000 - loss: 0.0026 - val_accuracy: 0.9917 - val_loss: 0.0872
# Epoch 41/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 1.0000 - loss: 0.0025 - val_accuracy: 0.9917 - val_loss: 0.0866
# Epoch 42/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 0.9917 - val_loss: 0.0838
# Epoch 43/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 1.0000 - loss: 0.0022 - val_accuracy: 0.9917 - val_loss: 0.0844
# Epoch 44/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9917 - val_loss: 0.0887
# Epoch 45/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 0.9917 - val_loss: 0.0885
# Epoch 46/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 100ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9917 - val_loss: 0.0903
# Epoch 47/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 1.0000 - loss: 0.0019 - val_accuracy: 0.9917 - val_loss: 0.0913
# Epoch 48/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9917 - val_loss: 0.0903
# Epoch 49/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 99ms/step - accuracy: 1.0000 - loss: 0.0017 - val_accuracy: 0.9917 - val_loss: 0.0906
# Epoch 50/50
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 1s 101ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 0.9917 - val_loss: 0.0901
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# RNN Model Accuracy: 99.17%
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         6
#            1       1.00      1.00      1.00         8
#            2       1.00      1.00      1.00         6
#            3       1.00      1.00      1.00        10
#            4       1.00      1.00      1.00         5
#            5       1.00      1.00      1.00         9
#            6       1.00      1.00      1.00         9
#            7       1.00      1.00      1.00         9
#            8       1.00      0.88      0.94        17
#            9       1.00      1.00      1.00        10
#           10       1.00      1.00      1.00         7
#           11       1.00      1.00      1.00         7
#           12       1.00      1.00      1.00        15
#           13       0.86      1.00      0.92         6
#           14       1.00      1.00      1.00        10
#           15       1.00      1.00      1.00        21
#           16       1.00      1.00      1.00        10
#           17       1.00      1.00      1.00         3
#           18       1.00      1.00      1.00        14
#           19       1.00      1.00      1.00         8
#           20       1.00      1.00      1.00        11
#           21       1.00      1.00      1.00         7
#           22       0.90      1.00      0.95         9
#           23       1.00      1.00      1.00        19
#           24       1.00      1.00      1.00         5
#
#     accuracy                           0.99       241
#    macro avg       0.99      1.00      0.99       241
# weighted avg       0.99      0.99      0.99       241

# %% [markdown]
# # Prediction System
# **Saving the created models**

# %%
import pickle
pickle.dump(tfidf,open('tfidf.pkl','wb'))
pickle.dump(knc, open('knc.pkl', 'wb'))
pickle.dump(mnb, open('mnb.pkl', 'wb'))
pickle.dump(model, open('rnn.pkl', 'wb'))

# %%
resume_1 = """
I am a motivated engineering student with a strong interest in data science, machine learning, and business analytics. I have hands-on experience working on real-world projects such as Credit Risk Modelling, Resume Screening Automation, and Customer Churn Prediction, where I applied data-driven techniques to solve practical problems.

My technical skill set includes Python, SQL, Scikit-learn, Pandas, NumPy, and data visualization tools like Tableau and Power BI. I am comfortable working with machine learning models for classification and prediction tasks, as well as performing exploratory data analysis and feature engineering to extract meaningful insights from data.

I enjoy bridging the gap between technical solutions and business needs by translating complex analysis into clear, actionable insights. I am eager to contribute to impactful projects, continuously learn new technologies, and grow as a data professional.

Education:
B.Tech in Biosciences and Bioengineering, IIT Guwahati

Key Skills:
- Machine Learning & Data Analytics  
- Python, SQL, Scikit-learn  
- Data Preprocessing & Feature Engineering  
- Model Evaluation & Optimization  
- Data Visualization (Tableau, Power BI)  
- Problem Solving & Communication  

If you are looking for a dedicated and analytical individual to contribute to data-driven initiatives, I would be excited to bring my skills and enthusiasm to your team.
"""

# %% [markdown]
# **Predicting Resume-1 by KNearestClassifier model**

# %%
import pickle

# Load the trained KNearest classifier model
clf = pickle.load(open('knc.pkl', 'rb'))

# Clean the input resume
cleaned_resume = resumeKeywords(resume_1)

# Transform the cleaned resume using the trained TfidfVectorizer
input_features = tfidf.transform([cleaned_resume])

# Make the prediction using the loaded classifier
prediction_id = clf.predict(input_features)[0]

category_name = category_mapping.get(prediction_id, "Unknown")

print("Predicted Category:", category_name)
print(prediction_id)
# Out:
# Predicted Category: Data Science
# 6

# %% [markdown]
# **Predicting Resume-1 by Multinomial Naive Bayes model**

# %%
import pickle

# Load the trained  Multinomial Naive Bayes model
mnb = pickle.load(open('mnb.pkl', 'rb'))

# Clean the input resume
cleaned_resume = resumeKeywords(resume_1)

# Transform the cleaned resume using the trained TfidfVectorizer
input_features = tfidf.transform([cleaned_resume])

# Make the prediction using the loaded classifier
prediction_id = mnb.predict(input_features)[0]

category_name = category_mapping.get(prediction_id, "Unknown")

print("Predicted Category:", category_name)
print(prediction_id)
# Out:
# Predicted Category: Data Science
# 6

# %% [markdown]
# **Predicting Resume-1 by RNN model**

# %%
import pickle
rnn = pickle.load(open('rnn.pkl', 'rb'))
# Define the maximum number of words to consider
max_words = 5000

# Tokenize and pad sequences
tokenizer = Tokenizer(num_words=max_words, split=' ')
tokenizer.fit_on_texts(df['Processed_Resume'])  # Use the same tokenizer used for training
cleaned_resume = resumeKeywords(resume_1)  # Clean the input resume

# Tokenize the cleaned input resume
input_sequence = tokenizer.texts_to_sequences([cleaned_resume])

input_sequence = pad_sequences(input_sequence, maxlen=100)

# Make the prediction using the loaded RNN model
predicted_probabilities = rnn.predict(input_sequence)

predictioon_id = np.argmax(predicted_probabilities)
# Map the category ID to the category name using category_mapping
category_name = category_mapping.get(prediction_id, "Unknown")

print("Predicted Category:", category_name)
print("Predicted Category ID:", prediction_id)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# Predicted Category: Data Science
# Predicted Category ID: 6

# %%
print('RNN Model Accuracy: {:.2f}%'.format(accuracy_rnn * 100))
# Out:
# RNN Model Accuracy: 99.17%
